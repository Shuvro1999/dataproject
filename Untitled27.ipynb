# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuvro1999/dataproject/blob/main/Untitled27.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Read the uploaded CSV file
df = pd.read_csv("/content/drive/MyDrive/insurance data_set/insurance.csv")

# Display the first few rows
print(df.head())
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# 2

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %% [markdown]
# 3

# %%
# Choose the target column to check (e.g., 'smoker')
target_column = 'smoker'

# Count values and calculate percentage
class_counts = df[target_column].value_counts()
class_percent = df[target_column].value_counts(normalize=True) * 100

# Combine into one DataFrame for readability
balance_check = pd.DataFrame({
    'Count': class_counts,
    'Percentage': class_percent.round(2)
})

# Print results
print(f"\nClass distribution for '{target_column}':\n")
print(balance_check)
# Out:
# Class distribution for 'smoker':
#
#         Count  Percentage
# smoker
# no       1064       79.52
# yes       274       20.48

# %%
# Display basic info
print("📄 Dataset Overview")
print("-" * 30)
print(f"Total rows: {df.shape[0]}")
print(f"Total columns: {df.shape[1]}\n")

# Loop through columns and describe each
print("📊 Column Descriptions")
print("-" * 30)

for col in df.columns:
    dtype = df[col].dtype

    print(f"Column: {col}")
    print(f"Type: {dtype}")

    if dtype == 'object':
        unique_vals = df[col].unique()
        print(f"Categories ({len(unique_vals)}): {list(unique_vals)}")
    else:
        min_val = df[col].min()
        max_val = df[col].max()
        print(f"Range: {min_val} to {max_val}")

    print("-" * 30)
# Out:
# 📄 Dataset Overview
# ------------------------------
# Total rows: 1338
# Total columns: 7
#
# 📊 Column Descriptions
# ------------------------------
# Column: age
# Type: int64
# Range: 18 to 64
# ------------------------------
# Column: sex
# Type: object
# Categories (2): ['female', 'male']
# ------------------------------
# Column: bmi
# Type: float64
# Range: 16.0 to 53.1
# ------------------------------
# Column: children
# Type: int64
# Range: 0 to 5
# ------------------------------
# Column: smoker
# Type: object
# Categories (2): ['yes', 'no']
# ------------------------------
# Column: region
# Type: object
# Categories (4): ['southwest', 'southeast', 'northwest', 'northeast']
# ------------------------------
# Column: expenses
# Type: float64
# Range: 1121.87 to 63770.43
# ------------------------------

# %% [markdown]
# 5

# %%
# Set the target column to evaluate
target_column = 'smoker'  # You can change this to any categorical column

# Get value counts and percentages
class_counts = df[target_column].value_counts()
class_percent = df[target_column].value_counts(normalize=True) * 100

# Combine into a summary DataFrame
summary = pd.DataFrame({
    'Count': class_counts,
    'Percentage': class_percent.round(2)
})

# Print the balance report
print(f"\n📊 Class Distribution in '{target_column}' Column:\n")
print(summary)

# Determine if dataset is balanced
imbalance_threshold = 0.7  # More than 70% of one class is considered imbalanced
is_balanced = class_percent.max() < (imbalance_threshold * 100)

# Print result
print("\n⚖️ Balance Check:")
if is_balanced:
    print("✅ The dataset is BALANCED.")
else:
    print("⚠️ The dataset is IMBALANCED.")
# Out:
# 📊 Class Distribution in 'smoker' Column:
#
#         Count  Percentage
# smoker
# no       1064       79.52
# yes       274       20.48
#
# ⚖️ Balance Check:
# ⚠️ The dataset is IMBALANCED.

# %% [markdown]
# 6

# %%
print("\n📊 Column-wise Data Summary")
print("=" * 50)

for col in df.columns:
    print(f"\n🔹 Column: {col}")
    dtype = df[col].dtype

    if pd.api.types.is_numeric_dtype(df[col]):
        unique_vals = df[col].nunique()

        # Assume discrete if few unique values
        if pd.api.types.is_integer_dtype(df[col]) and unique_vals < 10:
            # Discrete Numerical - treat like categorical
            counts = df[col].value_counts()
            percentages = df[col].value_counts(normalize=True) * 100
            summary = pd.DataFrame({'Count': counts, 'Percentage': percentages.round(2)})
            print("Type: Discrete Numerical")
            print(summary)
        else:
            # Continuous Numerical
            mean = df[col].mean()
            median = df[col].median()
            var = df[col].var()
            std = df[col].std()
            print("Type: Continuous Numerical")
            print(f"Mean: {mean:.2f}")
            print(f"Median: {median:.2f}")
            print(f"Variance: {var:.2f}")
            print(f"Standard Deviation: {std:.2f}")
    else:
        # Categorical
        counts = df[col].value_counts()
        percentages = df[col].value_counts(normalize=True) * 100
        summary = pd.DataFrame({'Count': counts, 'Percentage': percentages.round(2)})
        print("Type: Categorical")
        print(summary)
# Out:
# 📊 Column-wise Data Summary
# ...
#
# 🔹 Column: age
# Type: Continuous Numerical
# Mean: 39.21
# Median: 39.00
# Variance: 197.40
# Standard Deviation: 14.05
#
# 🔹 Column: sex
# Type: Categorical
#         Count  Percentage
# sex
# male      676       50.52
# female    662       49.48
#
# 🔹 Column: bmi
# Type: Continuous Numerical
# Mean: 30.67
# Median: 30.40
# Variance: 37.19
# Standard Deviation: 6.10
#
# 🔹 Column: children
# Type: Discrete Numerical
#           Count  Percentage
# children
# 0           574       42.90
# 1           324       24.22
# 2           240       17.94
# 3           157       11.73
# 4            25        1.87
# 5            18        1.35
#
# 🔹 Column: smoker
# Type: Categorical
#         Count  Percentage
# smoker
# no       1064       79.52
# yes       274       20.48
#
# 🔹 Column: region
# Type: Categorical
#            Count  Percentage
# region
# southeast    364       27.20
# southwest    325       24.29
# northwest    325       24.29
# ...

# %% [markdown]
# 7_bar_chart

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset


# Plot styling


# Loop through columns to find categorical or discrete numeric columns
for col in df.columns:
    if df[col].dtype == 'object' or (pd.api.types.is_integer_dtype(df[col]) and df[col].nunique() < 10):
        counts = df[col].value_counts()

        # Create bar chart
        plt.figure()
        counts.plot(kind='bar', color='cornflowerblue', edgecolor='black')
        plt.title(f"Bar Chart of '{col}'")
        plt.xlabel(col)
        plt.ylabel("Frequency")
        plt.xticks(rotation=0)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# 7_line_graph

# %%
import pandas as pd
import matplotlib.pyplot as plt





# Loop through columns to find continuous numerical columns
for col in df.columns:
    if pd.api.types.is_numeric_dtype(df[col]):
        unique_vals = df[col].nunique()

        # Consider continuous if many unique values
        if unique_vals >= 10:
            sorted_values = df[col].sort_values().reset_index(drop=True)
            plt.figure()
            plt.plot(sorted_values, color='teal')
            plt.title(f"Line Graph of '{col}' (sorted values)")
            plt.xlabel("Index")
            plt.ylabel(col)
            plt.tight_layout()
            plt.show()

# %% [markdown]
# 7_pie_chart

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Loop through columns to find binary categorical columns
for col in df.columns:
    if df[col].dtype == 'object' or df[col].dtype == 'int64':
        unique_vals = df[col].nunique()
        if unique_vals == 2:
            counts = df[col].value_counts()
            plt.figure()
            counts.plot.pie(
                autopct='%1.1f%%',
                startangle=90,
                colors=['#66b3ff', '#ff9999'],
                wedgeprops=dict(width=0.5)
            )
            plt.title(f"Pie Chart of '{col}'")
            plt.ylabel('')
            plt.tight_layout()
            plt.show()

# %% [markdown]
# 8

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset


# Convert categorical columns to numeric (optional, for full correlation matrix)
df_encoded = pd.get_dummies(df, drop_first=True)

# Compute correlation matrix
correlation = df_encoded.corr()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# 9

# %%
import pandas as pd



# Display original data types
print("Original Data Types:")
print(df.dtypes)

# Convert categorical columns using One-Hot Encoding
df_encoded = pd.get_dummies(df, columns=['sex', 'smoker', 'region'], drop_first=True)

# Display the new DataFrame
print("\nEncoded Data:")
print(df_encoded.head())
# Out:
# Original Data Types:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object
#
# Encoded Data:
#    age   bmi  children  expenses  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0  16884.92     False        True             False
# 1   18  33.8         1   1725.55      True       False             False
# 2   28  33.0         3   4449.46      True       False             False
# 3   33  22.7         0  21984.47      True       False              True
# 4   32  28.9         0   3866.86      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False
